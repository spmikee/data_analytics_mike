# %% [markdown]
# # Combining & organizing data

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import pandas as pd
import numpy as np
import fnmatch

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /Users/mike.spengler/Documents/GitHub/data_analytics_mike/Week_03

# %% [markdown]
# ## Importing the prepared rental apartments data

# %%
# Read data to pandas data frame
df_orig = pd.read_csv('apartments_data_prepared.csv', 
                      sep=',', 
                      encoding='utf-8')

# Copy of data with selected colums
columns = [ 'web-scraper-order', 
            'address_raw',
            'rooms', 
            'area', 
            'luxurious',
            'price',
            'price_per_m2']
df = df_orig[columns]

# Get number of rows and columns
print(df.shape)

# Show first records
df.head(5)
# Out:
# (865, 7)
#   web-scraper-order                          address_raw  rooms  area  \
# 0      1693998201-1    Neuhusstrasse 6, 8630 Rüti ZH, ZH    3.0  49.0
# 1      1693998201-2   Zürcherstrasse 1, 8173 Neerach, ZH    3.5  65.0
# 2      1693998201-4  Cramerstrasse 8-12, 8004 Zürich, ZH    2.0  54.0
# 3      1693998201-5    Rotachstrasse 33, 8003 Zürich, ZH    2.0  49.0
# 4     1693998201-16      Wolframplatz 1, 8045 Zürich, ZH    2.0  32.0
#
#    luxurious   price  price_per_m2
# 0          0  1441.0         29.41
# 1          0  1850.0         28.46
# 2          0  4853.0         89.87
# 3          0  4335.0         88.47
# 4          0  3515.0        109.84

# %% [markdown]
# ## Combining data from different sources

# %% [markdown]
# ### Reading rental apartment data with geocoded addresses

# %%
# Meaning of variables
# lat: geographical latitude
# lon: geographical longitude
# bfs_number: official municipality id
# bfs_name: official municipality name

# Geocoded data (i.e. data with latitude and longitude)
df_geo = pd.read_csv('apartments_data_geocoded.csv', 
                     sep=',', 
                     encoding='utf-8')

# Rename columns
df_geo = df_geo.rename(columns={'web-scrape':'web-scraper-order',
                                'address_ra':'address_raw',
                                'BFS_NUMMER':'bfs_number', 
                                'NAME':'bfs_name'})

# Show data
df_geo[['web-scraper-order',
        'address_raw',
        'lat', 
        'lon', 
        'bfs_number', 
        'bfs_name']].head()
# Out:
#   web-scraper-order                           address_raw        lat  \
# 0      1693998201-1     Neuhusstrasse 6, 8630 Rüti ZH, ZH  47.252171
# 1      1693998201-2    Zürcherstrasse 1, 8173 Neerach, ZH  47.513332
# 2      1693998201-5     Rotachstrasse 33, 8003 Zürich, ZH  47.370792
# 3     1693998201-16       Wolframplatz 1, 8045 Zürich, ZH  47.362282
# 4     1693998205-25  Badenerstrasse 67, 8953 Dietikon, ZH  47.407925
#
#         lon  bfs_number   bfs_name
# 0  8.845797         118  Rüti (ZH)
# 1  8.474851          88    Neerach
# 2  8.514748         261     Zürich
# 3  8.522193         261     Zürich
# 4  8.392561         243   Dietikon

# %% [markdown]
# ### Join geo-information to rental apartment data using .merge()

# %%
df2 = df.merge(df_geo[['web-scraper-order', 
                       'lat', 
                       'lon', 
                       'bfs_number', 
                       'bfs_name']], 
               on="web-scraper-order")
df2.head()
# Out:
#   web-scraper-order                           address_raw  rooms   area  \
# 0      1693998201-1     Neuhusstrasse 6, 8630 Rüti ZH, ZH    3.0   49.0
# 1      1693998201-2    Zürcherstrasse 1, 8173 Neerach, ZH    3.5   65.0
# 2      1693998201-5     Rotachstrasse 33, 8003 Zürich, ZH    2.0   49.0
# 3     1693998201-16       Wolframplatz 1, 8045 Zürich, ZH    2.0   32.0
# 4     1693998205-25  Badenerstrasse 67, 8953 Dietikon, ZH    3.5  105.0
#
#    luxurious   price  price_per_m2        lat       lon  bfs_number   bfs_name
# 0          0  1441.0         29.41  47.252171  8.845797         118  Rüti (ZH)
# 1          0  1850.0         28.46  47.513332  8.474851          88    Neerach
# 2          0  4335.0         88.47  47.370792  8.514748         261     Zürich
# 3          0  3515.0        109.84  47.362282  8.522193         261     Zürich
# 4          0  3200.0         30.48  47.407925  8.392561         243   Dietikon

# %% [markdown]
# ### Reading municipality-level data

# %%
# Meaning of variables:
# bfs_number: official municipality id
# bfs_name: official municipality name
# pop: number of residents (=population)
# pop_dens: population density (pop per km2)
# frg_pct: percentage foreigners
# emp: numer of employees

df_municip = pd.read_excel('municipality_data.xlsx', 
                           sheet_name='data_for_import')
df_municip.head(5)
# Out:
#    bfs_number            bfs_name      pop     pop_dens    frg_pct     emp  \
# 0         1.0     Aeugst am Albis   1981.0   250.442478  14.184755   442.0
# 1         2.0  Affoltern am Albis  12303.0  1161.756374  28.700317  6920.0
# 2         3.0          Bonstetten   5572.0   749.932705  16.564968  1014.0
# 3         4.0     Hausen am Albis   3751.0   275.808824  16.022394  1021.0
# 4         5.0            Hedingen   3778.0   578.560490  16.410799  1478.0
#
#   Steuerbares Einkommen, in Mio. Franken
# 0                                110.559
# 1                               411.7798
# 2                               230.5618
# 3                               164.4785
# 4                               166.5512

# %% [markdown]
# ### Join municipality data to rental apartment data using .merge()

# %%
# Merge needs a key which must be identical in both data sets (here the key is 'bfs_number')
df3 = df2.merge(df_municip[['bfs_number', 
                            'pop', 
                            'pop_dens', 
                            'frg_pct', 
                            'emp']], 
                on="bfs_number")
df3.head(5)
# Out:
#   web-scraper-order                           address_raw  rooms   area  \
# 0      1693998201-1     Neuhusstrasse 6, 8630 Rüti ZH, ZH    3.0   49.0
# 1    1693998233-172   Widacherstrasse 5, 8630 Rüti ZH, ZH    3.0  111.0
# 2    1693998256-331         Widenweg 14, 8630 Rüti ZH, ZH    3.0   58.0
# 3    1693998265-381              Rain 1, 8630 Rüti ZH, ZH    4.0  118.0
# 4    1693998276-419  Bachtelstrasse 24b, 8630 Rüti ZH, ZH    3.0   66.0
#
#    luxurious   price  price_per_m2        lat       lon  bfs_number  \
# 0          0  1441.0         29.41  47.252171  8.845797         118
# 1          0  2600.0         23.42  47.252087  8.854919         118
# 2          0  1490.0         25.69  47.253670  8.853993         118
# 3          0  3240.0         27.46  47.259834  8.851705         118
# 4          0  1450.0         21.97  47.266113  8.866872         118
#
#     bfs_name      pop     pop_dens    frg_pct     emp
# 0  Rüti (ZH)  12286.0  1221.272366  24.841283  5053.0
# 1  Rüti (ZH)  12286.0  1221.272366  24.841283  5053.0
# 2  Rüti (ZH)  12286.0  1221.272366  24.841283  5053.0
# 3  Rüti (ZH)  12286.0  1221.272366  24.841283  5053.0
# 4  Rüti (ZH)  12286.0  1221.272366  24.841283  5053.0

# %%
# Merge 'Steuerbares Einkommen, in Mio. Franken' from municipality data to apartment data
df3 = df3.merge(df_municip[['bfs_number', 'Steuerbares Einkommen, in Mio. Franken']], on='bfs_number')
df3.head(5)
# Out:
#   web-scraper-order                           address_raw  rooms   area  \
# 0      1693998201-1     Neuhusstrasse 6, 8630 Rüti ZH, ZH    3.0   49.0
# 1    1693998233-172   Widacherstrasse 5, 8630 Rüti ZH, ZH    3.0  111.0
# 2    1693998256-331         Widenweg 14, 8630 Rüti ZH, ZH    3.0   58.0
# 3    1693998265-381              Rain 1, 8630 Rüti ZH, ZH    4.0  118.0
# 4    1693998276-419  Bachtelstrasse 24b, 8630 Rüti ZH, ZH    3.0   66.0
#
#    luxurious   price  price_per_m2        lat       lon  bfs_number  \
# 0          0  1441.0         29.41  47.252171  8.845797         118
# 1          0  2600.0         23.42  47.252087  8.854919         118
# 2          0  1490.0         25.69  47.253670  8.853993         118
# 3          0  3240.0         27.46  47.259834  8.851705         118
# 4          0  1450.0         21.97  47.266113  8.866872         118
#
#     bfs_name      pop     pop_dens    frg_pct     emp  \
# 0  Rüti (ZH)  12286.0  1221.272366  24.841283  5053.0
# 1  Rüti (ZH)  12286.0  1221.272366  24.841283  5053.0
# 2  Rüti (ZH)  12286.0  1221.272366  24.841283  5053.0
# 3  Rüti (ZH)  12286.0  1221.272366  24.841283  5053.0
# 4  Rüti (ZH)  12286.0  1221.272366  24.841283  5053.0
#
#   Steuerbares Einkommen, in Mio. Franken
# 0                               376.5177
# 1                               376.5177
# 2                               376.5177
# 3                               376.5177
# 4                               376.5177

# %% [markdown]
# ### Export data to file

# %%
# Remove missing values which may have ocured from the merging process
df3 = df3.dropna()

# Check for missing values per column
print(df3.isna().sum())

# Count number of rows and columns
print(df3.shape)

# Export apartment data to file
df3.to_csv('apartments_data_enriched.csv',
            sep=',',
            encoding='utf-8')
# Out:
# web-scraper-order    0
# address_raw          0
# rooms                0
# area                 0
# luxurious            0
# price                0
# price_per_m2         0
# lat                  0
# lon                  0
# bfs_number           0
# bfs_name             0
# pop                  0
# pop_dens             0
# frg_pct              0
# emp                  0
# dtype: int64
# (816, 15)

# %% [markdown]
# ### Sorting data

# %%
# Sorting data by 'price' and 'area' with highest price above (ascending=False)
df3.sort_values(by=['price', 'area'], 
                ascending=False).head()
# Out:
#     web-scraper-order                             address_raw  rooms   area  \
# 85     1693998265-365    Gustav-Gull-Platz 4, 8004 Zürich, ZH    4.5  140.0
# 86     1693998265-366               Engweg 8, 8006 Zürich, ZH    4.5  140.0
# 46     1693998236-207        Etzelstrasse 35, 8038 Zürich, ZH    3.5  100.0
# 44     1693998236-197             Utoquai 37, 8008 Zürich, ZH    3.5  169.0
# 117    1693998285-475  Universitätstrasse 41, 8006 Zürich, ZH    4.5  140.0
#
#      luxurious   price  price_per_m2        lat       lon  bfs_number  \
# 85           0  9950.0         71.07  47.379471  8.531120         261
# 86           0  9170.0         65.50  47.385265  8.537632         261
# 46           1  9150.0         91.50  47.346546  8.530695         261
# 44           0  9000.0         53.25  47.363682  8.546781         261
# 117          0  8990.0         64.21  47.380440  8.547943         261
#
#     bfs_name     pop     pop_dens    frg_pct       emp
# 85    Zürich  420217  4778.994655  32.458468  491193.0
# 86    Zürich  420217  4778.994655  32.458468  491193.0
# 46    Zürich  420217  4778.994655  32.458468  491193.0
# 44    Zürich  420217  4778.994655  32.458468  491193.0
# 117   Zürich  420217  4778.994655  32.458468  491193.0

# %% [markdown]
# ### Aggregation of data

# %%
# Aggregation using .groupby()
df3[['rooms', 'price']].groupby(['rooms']).mean()
# Out:
#              price
# rooms
# 1.0    1306.346154
# 1.5    2092.054054
# 2.0    2138.775000
# 2.5    2414.993056
# 3.0    1950.434783
# 3.5    2664.813084
# 4.0    2798.200000
# 4.5    3065.211765
# 5.0    2773.750000
# 5.5    3523.094340
# 6.0    3833.333333
# 6.5    3623.625000
# 7.0    6350.000000
# 7.5    4765.000000
# 8.0    5500.000000
# 8.5    8500.000000

# %% [markdown]
# ## Reshaping data

# %% [markdown]
# ### Reshaping data using .stack() and .unstack()

# %%
df_sub = df3[['bfs_name', 'rooms', 'price', 'area']][:5]
print('Original shape')
print(df_sub, '\n')

df_sub_stacked = df_sub.stack()
print('Stacked')
print(df_sub_stacked, '\n')

# Using unstack
print('Unstacked (= back to original shape)')
print(df_sub_stacked.unstack())
# Out:
# Original shape
#     bfs_name  rooms   price   area
# 0  Rüti (ZH)    3.0  1441.0   49.0
# 1  Rüti (ZH)    3.0  2600.0  111.0
# 2  Rüti (ZH)    3.0  1490.0   58.0
# 3  Rüti (ZH)    4.0  3240.0  118.0
# 4  Rüti (ZH)    3.0  1450.0   66.0
#
# Stacked
# 0  bfs_name    Rüti (ZH)
#    rooms             3.0
#    price          1441.0
#    area             49.0
# 1  bfs_name    Rüti (ZH)
#    rooms             3.0
#    price          2600.0
#    area            111.0
# 2  bfs_name    Rüti (ZH)
#    rooms             3.0
#    price          1490.0
#    area             58.0
# 3  bfs_name    Rüti (ZH)
#    rooms             4.0
#    price          3240.0
#    area            118.0
# 4  bfs_name    Rüti (ZH)
#    rooms             3.0
#    price          1450.0
#    area             66.0
# dtype: object
#
# Unstacked (= back to original shape)
#     bfs_name rooms   price   area
# 0  Rüti (ZH)   3.0  1441.0   49.0
# 1  Rüti (ZH)   3.0  2600.0  111.0
# 2  Rüti (ZH)   3.0  1490.0   58.0
# 3  Rüti (ZH)   4.0  3240.0  118.0
# 4  Rüti (ZH)   3.0  1450.0   66.0

# %% [markdown]
# ### Reshaping data using .melt()

# %%
df_sub = df3[['rooms', 'price', 'area']][:5]
print('Original shape')
print(df_sub, '\n')

print('Reshaped using .melt()')
print(pd.melt(df, id_vars=['rooms'], value_vars=['price', 'area']))
# Out:
# Original shape
#    rooms   price   area
# 0    3.0  1441.0   49.0
# 1    3.0  2600.0  111.0
# 2    3.0  1490.0   58.0
# 3    4.0  3240.0  118.0
# 4    3.0  1450.0   66.0
#
# Reshaped using .melt()
#       rooms variable   value
# 0       3.0    price  1441.0
# 1       3.5    price  1850.0
# 2       2.0    price  4853.0
# 3       2.0    price  4335.0
# 4       2.0    price  3515.0
# ...     ...      ...     ...
# 1725    3.5     area    82.0
# 1726    4.0     area    73.0
# 1727    4.5     area   110.0
# 1728    3.0     area    68.0
# 1729    4.5     area   114.0
#
# [1730 rows x 3 columns]

# %% [markdown]
# ### Pivoting data using .pivot_table()

# %%
# Using pivot_table to reshape the data and calculate means, including price_per_m2
pd.pivot_table(df3[['rooms', 'price', 'area', 'price_per_m2']],
               index=['rooms'],
               values=['price', 'area', 'rooms', 'price_per_m2'],
               aggfunc=np.mean)
# Out:
#              area        price  price_per_m2
# rooms
# 1.0     32.057692  1306.346154     50.168077
# 1.5     35.972973  2092.054054     64.345676
# 2.0     54.475000  2138.775000     42.201750
# 2.5     67.340278  2414.993056     37.184861
# 3.0     68.574468  1942.659574     28.307447
# 3.5     89.500000  2664.813084     29.711355
# 4.0     96.900000  2798.200000     29.482000
# 4.5    114.587209  3073.290698     26.489186
# 5.0    103.500000  2773.750000     26.587500
# 5.5    153.685185  3537.777778     23.258519
# 6.0    667.666667  3833.333333     15.706667
# 6.5    248.375000  3623.625000     19.385625
# 7.0    175.000000  6350.000000     36.325000
# 7.5    205.000000  4765.000000     23.273333
# 8.0    160.000000  5500.000000     34.380000
# 8.5    210.000000  8500.000000     40.480000

# %%
# Create a pivot table to count the number of apartments by number of rooms and area category
pivot_count = pd.pivot_table(
    df3,
    values='web-scraper-order',
    index='rooms',
    columns=None,
    aggfunc='count'
)

print("Number of apartments by number of rooms:")
print(pivot_count)

# Description:
# The pivot table above shows how many apartments are available for each number of rooms.
# This helps to understand the distribution of apartment sizes in the dataset.
# Out:
# Number of apartments by number of rooms:
#        web-scraper-order
# rooms
# 1.0                   52
# 1.5                   37
# 2.0                   40
# 2.5                  144
# 3.0                   47
# 3.5                  214
# 4.0                   30
# 4.5                  172
# 5.0                    4
# 5.5                   54
# 6.0                    3
# 6.5                   16
# 7.0                    2
# 7.5                    3
# 8.0                    1
# 8.5                    1

# %%
# Create a pivot table with mean values per municipality
pivot_municipality = pd.pivot_table(
    df3,
    index='bfs_name',
    values=['rooms', 'area', 'price', 'price_per_m2'],
    aggfunc='mean'
)

# Sort by price and area, most expensive municipalities on top
pivot_municipality_sorted = pivot_municipality.sort_values(
    by=['price', 'area'],
    ascending=False
)

pivot_municipality_sorted.head()
# Out:
#                      area        price  price_per_m2  rooms
# bfs_name
# Rüschlikon     144.000000  6660.000000     46.250000    4.5
# Küsnacht (ZH)  136.333333  4891.666667     35.476667    4.5
# Nürensdorf     506.500000  4500.000000     17.605000    6.0
# Maur           138.500000  4250.000000     30.445000    4.5
# Obfelden       127.500000  4095.000000     31.910000    5.5

# %% [markdown]
# Evtl. gibt es eine relation zwischen raumanzahl und preis pro qm. ich glaube das der Preis sinke je mehr zimmer es het.

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Darwin | 24.5.0
# Datetime: 2025-10-02 10:24:58
# Python Version: 3.11.5
# -----------------------------------
